# %% [markdown]
# # Boolean Indexing

# %% [markdown]
# # (1) Calculating Boolean Statistics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
movie = pd.read_csv('movie.csv', index_col = 'movie_title')
movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
movie_2_hours = movie['duration'] > 120
movie_2_hours.head()
# Out:
# movie_title
# Avatar                                         True
# Pirates of the Caribbean: At World's End       True
# Spectre                                        True
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
# Name: duration, dtype: bool

# %%
movie_3_hours = movie['duration'].gt(120)
movie_3_hours.head()
# Out:
# movie_title
# Avatar                                         True
# Pirates of the Caribbean: At World's End       True
# Spectre                                        True
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
# Name: duration, dtype: bool

# %%
movie['duration'] == 120
# Out:
# movie_title
# Avatar                                        False
# Pirates of the Caribbean: At World's End      False
# Spectre                                       False
# The Dark Knight Rises                         False
# Star Wars: Episode VII - The Force Awakens    False
#                                               ...
# Signed Sealed Delivered                       False
# The Following                                 False
# A Plague So Pleasant                          False
# Shanghai Calling                              False
# My Date with Drew                             False
# Name: duration, Length: 4916, dtype: bool

# %%
movie['duration'].eq(120)
# Out:
# movie_title
# Avatar                                        False
# Pirates of the Caribbean: At World's End      False
# Spectre                                       False
# The Dark Knight Rises                         False
# Star Wars: Episode VII - The Force Awakens    False
#                                               ...
# Signed Sealed Delivered                       False
# The Following                                 False
# A Plague So Pleasant                          False
# Shanghai Calling                              False
# My Date with Drew                             False
# Name: duration, Length: 4916, dtype: bool

# %%
movie['duration'] != 120
# Out:
# movie_title
# Avatar                                        True
# Pirates of the Caribbean: At World's End      True
# Spectre                                       True
# The Dark Knight Rises                         True
# Star Wars: Episode VII - The Force Awakens    True
#                                               ...
# Signed Sealed Delivered                       True
# The Following                                 True
# A Plague So Pleasant                          True
# Shanghai Calling                              True
# My Date with Drew                             True
# Name: duration, Length: 4916, dtype: bool

# %%
movie['duration'].ne(120)
# Out:
# movie_title
# Avatar                                        True
# Pirates of the Caribbean: At World's End      True
# Spectre                                       True
# The Dark Knight Rises                         True
# Star Wars: Episode VII - The Force Awakens    True
#                                               ...
# Signed Sealed Delivered                       True
# The Following                                 True
# A Plague So Pleasant                          True
# Shanghai Calling                              True
# My Date with Drew                             True
# Name: duration, Length: 4916, dtype: bool

# %%
movie['language'] == 'English'
# Out:
# movie_title
# Avatar                                         True
# Pirates of the Caribbean: At World's End       True
# Spectre                                        True
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
#                                               ...
# Signed Sealed Delivered                        True
# The Following                                  True
# A Plague So Pleasant                           True
# Shanghai Calling                               True
# My Date with Drew                              True
# Name: language, Length: 4916, dtype: bool

# %%
movie['language'].str.contains('Eng')
# Out:
# movie_title
# Avatar                                        True
# Pirates of the Caribbean: At World's End      True
# Spectre                                       True
# The Dark Knight Rises                         True
# Star Wars: Episode VII - The Force Awakens     NaN
#                                               ...
# Signed Sealed Delivered                       True
# The Following                                 True
# A Plague So Pleasant                          True
# Shanghai Calling                              True
# My Date with Drew                             True
# Name: language, Length: 4916, dtype: object

# %%
movie['imdb_score'].between(7, 9)
# Out:
# movie_title
# Avatar                                         True
# Pirates of the Caribbean: At World's End       True
# Spectre                                       False
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens     True
#                                               ...
# Signed Sealed Delivered                        True
# The Following                                  True
# A Plague So Pleasant                          False
# Shanghai Calling                              False
# My Date with Drew                             False
# Name: imdb_score, Length: 4916, dtype: bool

# %% [markdown]
# # (2) Constructing Multiple Boolean Conditions

# %%
movie = pd.read_csv('movie.csv', index_col = 'movie_title')
movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
criteria1 = movie['imdb_score'] > 8
criteria1
# Out:
# movie_title
# Avatar                                        False
# Pirates of the Caribbean: At World's End      False
# Spectre                                       False
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
#                                               ...
# Signed Sealed Delivered                       False
# The Following                                 False
# A Plague So Pleasant                          False
# Shanghai Calling                              False
# My Date with Drew                             False
# Name: imdb_score, Length: 4916, dtype: bool

# %%
criteria2 = movie['content_rating'] == 'PG-13'
criteria2
# Out:
# movie_title
# Avatar                                         True
# Pirates of the Caribbean: At World's End       True
# Spectre                                        True
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
#                                               ...
# Signed Sealed Delivered                       False
# The Following                                 False
# A Plague So Pleasant                          False
# Shanghai Calling                               True
# My Date with Drew                             False
# Name: content_rating, Length: 4916, dtype: bool

# %%
criteria3 = (movie['imdb_score'] > 8) & (movie['content_rating'] == 'PG-13')
criteria3
# Out:
# movie_title
# Avatar                                        False
# Pirates of the Caribbean: At World's End      False
# Spectre                                       False
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
#                                               ...
# Signed Sealed Delivered                       False
# The Following                                 False
# A Plague So Pleasant                          False
# Shanghai Calling                              False
# My Date with Drew                             False
# Length: 4916, dtype: bool

# %%
criteria4 = (movie['imdb_score'] > 8) | (movie['content_rating'] == 'PG-13')
criteria4
# Out:
# movie_title
# Avatar                                         True
# Pirates of the Caribbean: At World's End       True
# Spectre                                        True
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
#                                               ...
# Signed Sealed Delivered                       False
# The Following                                 False
# A Plague So Pleasant                          False
# Shanghai Calling                               True
# My Date with Drew                             False
# Length: 4916, dtype: bool

# %%
criteria5 = (movie['imdb_score'].gt(8)) | (movie['content_rating'].eq('PG-13'))
criteria5
# Out:
# movie_title
# Avatar                                         True
# Pirates of the Caribbean: At World's End       True
# Spectre                                        True
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
#                                               ...
# Signed Sealed Delivered                       False
# The Following                                 False
# A Plague So Pleasant                          False
# Shanghai Calling                               True
# My Date with Drew                             False
# Length: 4916, dtype: bool

# %% [markdown]
# # (3) Filtering With Boolean Indexing

# %%
criteria3.value_counts()
# Out:
# False    3292
# True     1624
# dtype: int64

# %%
movie[criteria3]
# Out:
#                                           color      director_name  \
# movie_title
# Avatar                                    Color      James Cameron
# Pirates of the Caribbean: At World's End  Color     Gore Verbinski
# Spectre                                   Color         Sam Mendes
# The Dark Knight Rises                     Color  Christopher Nolan
# John Carter                               Color     Andrew Stanton
# ...                                         ...                ...
# The Signal                                Color     William Eubank
# The Last Waltz                            Color    Martin Scorsese
# Primer                                    Color      Shane Carruth
# The Mongol King                           Color    Anthony Vallone
# Shanghai Calling                          Color        Daniel Hsia
#
#                                           num_critic_for_reviews  duration  \
# movie_title
# ...

# %%
movie.loc[criteria3]
# Out:
#                                           color      director_name  \
# movie_title
# Avatar                                    Color      James Cameron
# Pirates of the Caribbean: At World's End  Color     Gore Verbinski
# Spectre                                   Color         Sam Mendes
# The Dark Knight Rises                     Color  Christopher Nolan
# John Carter                               Color     Andrew Stanton
# ...                                         ...                ...
# The Signal                                Color     William Eubank
# The Last Waltz                            Color    Martin Scorsese
# Primer                                    Color      Shane Carruth
# The Mongol King                           Color    Anthony Vallone
# Shanghai Calling                          Color        Daniel Hsia
#
#                                           num_critic_for_reviews  duration  \
# movie_title
# ...

# %%
movie_filtered = movie[criteria3][['imdb_score', 'content_rating']]
movie_filtered
# Out:
#                                           imdb_score content_rating
# movie_title
# Avatar                                           7.9          PG-13
# Pirates of the Caribbean: At World's End         7.1          PG-13
# Spectre                                          6.8          PG-13
# The Dark Knight Rises                            8.5          PG-13
# John Carter                                      6.6          PG-13
# ...                                              ...            ...
# The Signal                                       6.1          PG-13
# The Last Waltz                                   8.2             PG
# Primer                                           7.0          PG-13
# The Mongol King                                  7.8          PG-13
# Shanghai Calling                                 6.3          PG-13
#
# [1624 rows x 2 columns]

# %%
movie_filtered = movie.loc[criteria3, ['imdb_score', 'content_rating']]
movie_filtered
# Out:
#                                           imdb_score content_rating
# movie_title
# Avatar                                           7.9          PG-13
# Pirates of the Caribbean: At World's End         7.1          PG-13
# Spectre                                          6.8          PG-13
# The Dark Knight Rises                            8.5          PG-13
# John Carter                                      6.6          PG-13
# ...                                              ...            ...
# The Signal                                       6.1          PG-13
# The Last Waltz                                   8.2             PG
# Primer                                           7.0          PG-13
# The Mongol King                                  7.8          PG-13
# Shanghai Calling                                 6.3          PG-13
#
# [1624 rows x 2 columns]
